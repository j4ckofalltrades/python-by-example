# %% [markdown]
# <div style="background: linear-gradient(135deg, #F37726 0%, #FF9A56 100%); padding: 10px; border-radius: 10px; color: white;">
#
# # Conditionals
#
# </div>

# %% [markdown]
# ## Boolean (or Logical) Operators

# %% [markdown]
# ### `and` Truth Table
#
# | X     | Y     | X and Y |
# |-------|-------|---------|
# | True  | True  | True    |
# | True  | False | False   |
# | False | True  | False   |
# | False | False | False   |
#
# ### `or` Truth Table
#
# | X     | Y     | X or Y |
# |-------|-------|--------|
# | True  | True  | True   |
# | True  | False | True   |
# | False | True  | True   |
# | False | False | False  |
#
# ### `not` Truth Table
#
# | X     | not(X) |
# |-------|--------|
# | True  | False  |
# | False | True   |

# %%
print(True and False)
print(False or True)
print(not True)
print(not False)

# %% [markdown]
# ### Comparison Operators
#
# - The equality operator is `==`
# - The inequality operator is `!=`
# - The greater than and less than operators are `>` and `<` respectively
# - The greater than or equal to and less than or equal to operators are `>=` and `<=` respectively

# %%
print(1 == 1)
print(2 == 1)

print(1 != 1)
print(2 != 1)

print(1 < 10)
print(1 > 10)
print(2 <= 2)
print(2 >= 2)

# %% [markdown]
# ### Control Flow
#
# The `if`, `elif`, and `else` keywords can be used to execute code only when certain conditions are met.
#
# Note: `elif` and `else` are optional.
#
# ```text
# if <expr>:
#     # code that is executed when the `if` expression is true
# elif <other_expr>:
#     # code that is executed when the `elif` expression is true
# else:
#     # code that is executed when the `if` and `elif` expressions are false
# ```

# %%
# Try changing this value and run the cell again
some_var = 5

if some_var > 10:
    print("some_var is larger than 10.")
elif some_var < 10:
    print("some_var is smaller than 10.")
else:
    print("some_var is indeed 10.")

# %% [markdown]
# ### Truthiness and Falsiness
#
# What values are considered _falsy_? (Check with the `bool` function.)
#
# - Zero values of any numeric type e.g. `0`, `0.0`
# - Empty strings `""`
# - Empty collections e.g. `list`, `set`, `tuple`, `dict`
# - `None`
# - `False`
#
# Note: Collections e.g. `list`, `set`, etc. will be covered in a later notebook.

# %% [markdown]
# The following are examples of _falsy_ values.

# %%
print(f"bool(0): {bool(0)}")
print(f"bool(0.0): {bool(0.0)}")
print(f"bool(\"\"): {bool("")}")
print(f"bool([]): {bool([])}")
print(f"bool(()): {bool(())}")
print(f"bool(None): {bool(None)}")
print(f"bool(False): {bool(False)}")

# %% [markdown]
# The following are examples of _truthy_ values.

# %%
print(f"bool(1): {bool(1)}")
print(f"bool(-1): {bool(-1)}")
print(f'bool("hello"): {bool("hello")}')
print(f"bool([0]): {bool([0])}")

# A non-empty set is also truthy
one_element_set = {0}
print(f"bool(one_element_set): {bool(one_element_set)}")  # => True (non-empty set)

# %% [markdown]
# ### Practical truthiness
#
# A very common Python pattern — checking if a collection is empty:
#
# ```python
# items = []
# if items:
#     print("You have items in your cart")
# else:
#     print("Your cart is empty")  # This runs
# ```

# %% [markdown]
# > **Indentation matters:** Python uses indentation to define code blocks. Inconsistent indentation is one of the most common beginner errors.
#
# > **`=` vs `==`:** A single `=` *assigns* a value; `==` *compares* two values. Using `=` inside an `if` condition is a very common mistake.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4CAF50 0%, #81C784 100%); padding: 7.5px; border-radius: 10px; color: white;">
#
# ## 💡 Test your knowledge
#
# </div>
#
# Generate test questions by clicking on the code block below and then pressing `Ctrl + Enter`.

# %%
import micropip
await micropip.install('jupyterquiz')

import base64
import json
from jupyterquiz import display_quiz

display_quiz(json.loads(base64.b64decode("...")))

# %% [markdown]
# <div style="background: linear-gradient(135deg, #2196F3 0%, #64B5F6 100%); padding: 7.5px; border-radius: 10px; color: white;">
#
# ## ✏️ Write some code
#
# </div>

# %% [markdown]
# ### Exercise 1: Boolean logic
# Create variables for weather conditions and write code that prints an activity recommendation.
#
# **Expected Output (sunny=True, warm=False):**
# ```
# Weather: Sunny=True, Warm=False
# Recommendation: Go for a hike!
# ```

# %%
# Try different combinations of True/False
is_sunny = True
is_warm = False

# TODO: Use if/elif/else with and/or to recommend an activity:
# Sunny and warm -> "Go to the beach!"
# Sunny but not warm -> "Go for a hike!"
# Not sunny but warm -> "Visit a museum!"
# Not sunny and not warm -> "Stay inside and read!"

print(f"Weather: Sunny={is_sunny}, Warm={is_warm}")

# %% [markdown]
# ### Exercise 2: Grade calculator
# Convert a numerical grade (0-100) to a letter grade (A: 90-100, B: 80-89, C: 70-79, D: 60-69, F: below 60).
#
# **Expected Output:**
# ```
# Grade 85 is: B
# ```

# %%
# Change this value to test different grades
grade = 85

# TODO: Use if/elif/else to determine the letter grade
# TODO: Print: f"Grade {grade} is: {letter}"

# %% [markdown]
# ### Exercise 3: Truthiness check
# Test the truthiness of different values by printing `bool()` for each.
#
# **Expected Output:**
# ```
# Empty string '': False
# String with spaces '   ': True
# Number 0: False
# Negative number -1: True
# ```

# %%
# TODO: Use bool() to test each value and print the results
# Test: empty string "", string with spaces "   ", 0, and -1
