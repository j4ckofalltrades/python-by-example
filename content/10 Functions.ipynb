# %% [markdown]
# <div style="background: linear-gradient(135deg, #F37726 0%, #FF9A56 100%); padding: 10px; border-radius: 10px; color: white;">
#
# # Functions
#
# </div>
#
# A **function** is a self-contained block of code that encapsulates a specific task or related group of tasks.

# %% [markdown]
# ## Why functions?
#
# By now you've written conditionals, loops, list operations, and more. You've probably noticed yourself writing similar patterns more than once.
#
# **Functions let you name a block of code, give it parameters, and reuse it anywhere.** Instead of copying logic, you write it once and call it by name. This is how real programs are organized.

# %% [markdown]
# ## Syntax
#
# Create functions with the `def` keyword. A function can have zero or more arguments.
#
# To use a function, you need to _call_ it. A function call consists of the function name and
# its arguments.
#
# A function can also optionally _return_ a value to the caller by using the `return` keyword.

# %%
# A function that returns a value
def add(x, y):
    return x + y

result = add(5, 6)
print(f"Result: {result}")  # => 11

# Keyword arguments: call with argument names (order doesn't matter)
result2 = add(y=6, x=5)
print(f"Result2: {result2}")  # => 11

# %% [markdown]
# ### Positional arguments
#
# The most straightforward way to pass arguments to a Python function is with **positional arguments** (also called **required arguments**).

# %%
def format_item_price(qty, item, price):
    print(f"{qty} {item} cost ${price} each")
    
# Call with positional arguments (order matters)
format_item_price(3, "apples", 1.25)

# %% [markdown]
# ### Keyword arguments
#
# Functions can also be called by specifying arguments in the form of `<keyword>=<value>`.

# %%
format_item_price(price=1.74, qty=6, item="bananas")

# %% [markdown]
# Positional and keyword arguments can be combined, but positional arguments must come first.

# %%
format_item_price(2, item="oranges", price=0.99)

# %% [markdown]
# ## `None` return value
#
# A function without a `return` statement returns `None`:

# %%
def greet(name):
    print(f"Hello, {name}!")  # prints but does not return

result = greet("Alice")
print(f"Return value: {result}")  # => None

# %% [markdown]
# ## Multiple return values
#
# Python returns multiple values naturally via tuples — a powerful feature:

# %%
def min_max(numbers):
    return min(numbers), max(numbers)

low, high = min_max([3, 1, 4, 1, 5, 9, 2, 6])
print(f"Min: {low}, Max: {high}")  # => Min: 1, Max: 9

# %%
def factorial(n):
    if n == 0:        # base case
        return 1
    return n * factorial(n - 1)  # recursive case

print(factorial(5))  # => 120  (5 * 4 * 3 * 2 * 1)

# %%
def greet(name: str) -> str:
    return f"Hello, {name}!"

def add(x: int, y: int) -> int:
    return x + y

def get_stats(numbers: list) -> tuple:
    return min(numbers), max(numbers)

print(greet("Alice"))
print(add(3, 4))

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4CAF50 0%, #81C784 100%); padding: 7.5px; border-radius: 10px; color: white;">
#
# ## 💡 Test your knowledge
#
# </div>
#
# Generate test questions by clicking on the code block below and then pressing `Ctrl + Enter`.

# %%
import micropip
await micropip.install('jupyterquiz')

import base64
import json
from jupyterquiz import display_quiz

display_quiz(json.loads(base64.b64decode("...")))

# %% [markdown]
# <div style="background: linear-gradient(135deg, #2196F3 0%, #64B5F6 100%); padding: 7.5px; border-radius: 10px; color: white;">
#
# ## ✏️ Write some code
#
# </div>

# %% [markdown]
# ### Exercise 1: Basic function
# Write a function called `greet_user` that takes a name and returns a greeting string.
#
# **Expected Output:**
# ```
# Hello, Alice!
# ```

# %%
def greet_user(name: str) -> str:
    # TODO: return a greeting string
    pass

print(greet_user("Alice"))

# %% [markdown]
# ### Exercise 2: Function with return value
# Create a function `calculate_area(length, width)` that returns the area.
#
# **Expected Output:**
# ```
# The area is 35 square units
# ```

# %%
def calculate_area(length: float, width: float) -> float:
    # TODO: return length * width
    pass

area = calculate_area(7, 5)
print(f"The area is {area} square units")

# %% [markdown]
# ### Exercise 3: Multiple return values
# Write a function `describe_list(numbers)` that returns both the minimum and maximum values.
#
# **Expected Output:**
# ```
# Min: 1, Max: 9
# ```

# %%
def describe_list(numbers: list) -> tuple:
    # TODO: return min and max
    pass

low, high = describe_list([3, 1, 4, 1, 5, 9, 2, 6])
print(f"Min: {low}, Max: {high}")

# %% [markdown]
# ### Exercise 4: Keyword arguments
# Create a function `introduce(name, age, city)`. Call it using keyword arguments in any order.
#
# **Expected Output:**
# ```
# Hi, I'm Alice, I'm 25 years old and I live in New York
# ```

# %%
def introduce(name: str, age: int, city: str) -> str:
    # TODO: return the introduction message
    pass

print(introduce(city="New York", name="Alice", age=25))

# %% [markdown]
# ### Exercise 5: Temperature converter
# Create `celsius_to_fahrenheit(celsius)` using the formula F = (C × 9/5) + 32.
#
# **Expected Output:**
# ```
# 25°C is equal to 77.0°F
# ```

# %%
def celsius_to_fahrenheit(celsius: float) -> float:
    # TODO: apply the conversion formula and return
    pass

temp_c = 25
temp_f = celsius_to_fahrenheit(temp_c)
print(f"{temp_c}°C is equal to {temp_f}°F")
